# %%
import pandas as pd
restaurants_df = pd.read_csv('Restaurants.csv')
license_df = pd.read_csv('Liquor_Licenses.csv')
restaurants_df.rename(columns = {'X':'Latitude', 'Y':'Longitude'}, inplace = True)
license_df.rename(columns = {'street_address':'Address', 'dba':'Name', 'X':'Latitude', 'Y':'Longitude'}, inplace = True)

# %%
all_df = pd.merge(restaurants_df, license_df, how='outer', on='Address')
all_df = all_df.drop_duplicates(
  subset = ['Name_x', 'Address'],
  keep = 'last').reset_index(drop = True)
all_df = all_df[~all_df['Name_x'].isna()] #get rid of places that are not restaurants
#show John all_df[['Name_x', 'Name_y', 'Address']]

all_df.loc[all_df['number'].isna()==True, 'Serve_Liquor'] = 'No' #create new column, number stands for liquor license number
all_df.loc[all_df['number'].isna()==False, 'Serve_Liquor'] = 'Yes'

# %%
all_df[all_df['Serve_Liquor'] == 'Yes'] #there are 412 restaurants who serve liquor
all_df[all_df['Serve_Liquor'] == 'No'] #there are 1940 restaurants who don't...
all_df
# Out:
#       Latitude_x  Longitude_x  Establishment_ID  \
# 0     -83.048647    42.335696        51622592.0
# 1     -83.048647    42.335696        51622594.0
# 2     -83.048647    42.335696        51622842.0
# 3     -83.048647    42.335696        51622595.0
# 4     -83.141277    42.435563            3928.0
# ...          ...          ...               ...
# 2347  -83.019169    42.338190            3425.0
# 2348  -83.096549    42.366752             865.0
# 2349  -83.128168    42.406004            1894.0
# 2350  -83.224794    42.329291            3673.0
# 2351  -83.159646    42.403265            1282.0
#
#                                    Name_x                Address Zip_Code  \
# 0                       1509 Populace LLC       1509 Broadway St    48226
# 1            Albena- Taste Everything LLC       1509 Broadway St    48226
# 2     HMWW Food LLC dba Karl's The Siren        1509 Broadway St    48226
# 3          The Wurlitzer MT DBA Candy Bar       1509 Broadway St    48226
# 4                    1917 American Bistro        19416 Livernois    48221
# ...                                   ...                    ...      ...
# 2347           They Say/Dunco Holding LLC  267 Joseph Campau Ave    48207
# 2348                  Thirkell Elementary     7724 Fourteenth St    48206
# 2349         Thurgood Marshall Elementary       15531 Linwood St    48238
# 2350   Tijuana's Authenic Mexican Kitchen          18940 Ford Rd    48228
# 2351                         Tim Horton's      15340 Wyoming Ave    48238
#
#                                Owner License_Number         License_Type  \
# 0     Populace Coffee/Andrew Heppner         226550  Fixed Establishment
# 1                      Garrett Lipar         229298  Fixed Establishment
# 2                          Matt Wang         238151  Fixed Establishment
# 3                      HM Ventures 6         229302  Fixed Establishment
# 4                    Donald Studvent         065464  Fixed Establishment
# ...                              ...            ...                  ...
# 2347               Terry Payne:  CEO         055109  Fixed Establishment
# 2348      Detroit Board of Education         034897  Fixed Establishment
# 2349      Detroit Board Of Education         037535  Fixed Establishment
# 2350  Tijuana's Authenic Mexican Kit         071393  Fixed Establishment
# 2351                 Copeland TH Inc         077771  Fixed Establishment
#
#      Most_Recent_License_Date  ... group_ type subtype  statute  number  \
# 0      2019/04/27 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 1      2019/04/26 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 2      2019/04/16 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 3      2019/04/16 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 4      2013/04/30 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# ...                       ...  ...    ...  ...     ...      ...     ...
# 2347   1970/01/01 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 2348   2019/04/15 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 2349   2020/06/01 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 2350   2019/04/21 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
# 2351   1970/01/01 00:00:00+00  ...    NaN  NaN     NaN      NaN     NaN
#
#       status  ownership_transferable  location_transferable ObjectId_y  \
# 0        NaN                     NaN                    NaN        NaN
# 1        NaN                     NaN                    NaN        NaN
# 2        NaN                     NaN                    NaN        NaN
# 3        NaN                     NaN                    NaN        NaN
# 4        NaN                     NaN                    NaN        NaN
# ...      ...                     ...                    ...        ...
# 2347     NaN                     NaN                    NaN        NaN
# 2348     NaN                     NaN                    NaN        NaN
# 2349     NaN                     NaN                    NaN        NaN
# 2350     NaN                     NaN                    NaN        NaN
# 2351     NaN                     NaN                    NaN        NaN
#
#      Serve_Liquor
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ...           ...
# 2347           No
# 2348           No
# 2349           No
# 2350           No
# 2351           No
#
# [2352 rows x 31 columns]
